# %%
# Bronze Layer - Load raw tables (NO SQL, NO %sql)

orders = spark.table("default.orders")
customers = spark.table("default.customers")
products = spark.table("default.products")

print("Orders:")
orders.show()

print("Customers:")
customers.show()

print("Products:")
products.show()
# Out:
# Orders:
# +--------+-----------+----------+--------+-----+-------------------+
# |order_id|customer_id|product_id|quantity|price|          timestamp|
# +--------+-----------+----------+--------+-----+-------------------+
# |       1|        101|      2001|       2| 15.5|2024-01-01 10:00:00|
# |       2|        102|      2002|       1| 20.0|2024-01-01 11:00:00|
# |       3|       NULL|      2003|       1| 10.0|2024-01-01 12:00:00|
# |       4|        101|      2001|       1| 15.5|2024-01-02 09:00:00|
# |       5|        103|      2002|       3| 20.0|2024-01-02 10:00:00|
# +--------+-----------+----------+--------+-----+-------------------+
#
# Customers:
# +-----------+-------------+-----------------+-------+
# |customer_id|customer_name|            email|country|
# +-----------+-------------+-----------------+-------+
# |        101|        Alice|  alice@email.com| France|
# |        102|          Bob|    bob@email.com|Germany|
# |        103|      Charlie|charlie@email.com|Belgium|
# ...
